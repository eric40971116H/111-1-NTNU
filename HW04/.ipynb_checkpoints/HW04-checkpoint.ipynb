# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
temp = []
for page in range (0,10):

#url = 'https://movies.yahoo.com.tw/movieinfo_review.html/id=14151?sort=update_ts&order=desc&page='

    res = requests.get("https://movies.yahoo.com.tw/movieinfo_review.html/id=14151?sort=update_ts&order=desc&page="+str(page))
    
    res.encoding="utf-8"
    
    txt = res.text

    soup = BeautifulSoup(txt,'html.parser')
    
    lst = soup.find_all('form', class_='form_good')


    for x in lst:
    
        comment = x.find_all('span')
    
        for y in comment:
        
            comment2 = y.text
        print(comment2)
        
    for x in lst:
    
        comment = x.find_all('span')
    
        for y in comment:
        
            comment2 = y.text
        temp.append(comment2)
# Out:
# 舒莉有點太瘦，沒有美隊的強壯感
# 但劇情上還不錯
# 樓下說黑亞當贏過黑豹2 我聽你放屁 (黑亞當後面我看到睡著 老套的美式超人主義 亂七八糟的特效) 黑豹2這部一樣承襲黑豹1的精神 宏偉的世界觀 每個角色的刻劃很清楚 不會輕描淡寫 畫面真得很漂亮 看到另一個國家真得很有驚喜感 有水行俠和阿凡達的FU 美中不足就是黑豹變女生 但瑕不掩瑜
# 整體體感黑亞當>黑豹2>奇異博士2>=雷神4但如果只比劇情的話黑豹2>黑亞當;其實黑豹2太攏長了不夠緊湊動作戲太少缺少緊張感,但不會是看出來覺得被騙的電影,所以我個人覺得整體看下來漫威今年拍的沒一片贏過DC
# 劇情硬湊連貫的不合理，主角的心路歷程難引起共鳴，整部作品只是為了延續商品價值而硬湊端上的菜色怎麼可能會好吃！
# 根據外媒報導，黑豹2的劇本在男主角查德維克.博斯曼過世後,導演和編劇重新翻新改寫,讓舒莉來承接黑豹的身分實在很難說服觀眾,舒莉太薄弱，感覺像演貓女......
# 飾演拉瑪達皇后的安琪拉貝瑟(Angela Bassett) 是本片表演最精彩的角色,可以準備入圍奧斯卡女配角提名了
# 我個人是覺得比第一集好看，滿有深度的，略帶一些阿凡達的影子，不過小部分真的有悶到~
# 這部主要集中在內心戲的部分,某些橋段還不錯,一些橋段就邏輯上實在不太能夠理解,蠻粗糙的,女王還是演得相當好(肌肉也很厲害),整部片最可惜是女主角要挑起主角的大樑以演技來說還是蠻勉強的
#
# 整體而言更令人緬懷Chadwick Aaron Boseman
# 真的很難看……最難看的漫威系列了……我的天啊！弱……別騙了……真的很難看
# 只有沙丘睡著 其它所有的片通通都五顆星
# 故事很拖，女主角感覺像小女孩，演起來沒有靈魂，像是素人在演戲
# 舒莉有點太瘦，沒有美隊的強壯感
# 但劇情上還不錯
# 樓下說黑亞當贏過黑豹2 我聽你放屁 (黑亞當後面我看到睡著 老套的美式超人主義 亂七八糟的特效) 黑豹2這部一樣承襲黑豹1的精神 宏偉的世界觀 每個角色的刻劃很清楚 不會輕描淡寫 畫面真得很漂亮 看到另一個國家真得很有驚喜感 有水行俠和阿凡達的FU 美中不足就是黑豹變女生 但瑕不掩瑜
# 整體體感黑亞當>黑豹2>奇異博士2>=雷神4但如果只比劇情的話黑豹2>黑亞當;其實黑豹2太攏長了不夠緊湊動作戲太少缺少緊張感,但不會是看出來覺得被騙的電影,所以我個人覺得整體看下來漫威今年拍的沒一片贏過DC
# 劇情硬湊連貫的不合理，主角的心路歷程難引起共鳴，整部作品只是為了延續商品價值而硬湊端上的菜色怎麼可能會好吃！
# 根據外媒報導，黑豹2的劇本在男主角查德維克.博斯曼過世後,導演和編劇重新翻新改寫,讓舒莉來承接黑豹的身分實在很難說服觀眾,舒莉太薄弱，感覺像演貓女......
# 飾演拉瑪達皇后的安琪拉貝瑟(Angela Bassett) 是本片表演最精彩的角色,可以準備入圍奧斯卡女配角提名了
# 我個人是覺得比第一集好看，滿有深度的，略帶一些阿凡達的影子，不過小部分真的有悶到~
# 這部主要集中在內心戲的部分,某些橋段還不錯,一些橋段就邏輯上實在不太能夠理解,蠻粗糙的,女王還是演得相當好(肌肉也很厲害),整部片最可惜是女主角要挑起主角的大樑以演技來說還是蠻勉強的
#
# 整體而言更令人緬懷Chadwick Aaron Boseman
# 真的很難看……最難看的漫威系列了……我的天啊！弱……別騙了……真的很難看
# 只有沙丘睡著 其它所有的片通通都五顆星
# 故事很拖，女主角感覺像小女孩，演起來沒有靈魂，像是素人在演戲
# 比奇異博士2 雷神好看多了
# 有劇情 有笑點 有哭點
# 真的很不推薦，前面母后挺身而出，到後來吧為了解救小女孩而過世，雖然覺得故事有點長，但鋪成的還可以；但後面對於公主如何變成黑豹，以及打到敵人的部分真的有點草率！（還有高科技就一定能研發出類鋼鐵人這點，也很不能接受= =）
# 漫威上映基本上一定會去看，但這部真的缺少了緊張刺激的感覺，也沒有爽度，最讓我滿頭問好的地方就是，身為一個世界最強之國也太不經打了吧，動不動就被入侵然後除了黑豹以外都被當菜雞在打......黑豹1好看多了
# 顏值最爛的一部片，東湊西湊，劇情描述好爛，有盜版的鋼鐵人、水行俠、阿凡達，還好特效音樂還算可以
# 有阿凡達的影子就打了對折
#
# 全片只有（羽蛇神）這3個字最酷
#
# 在來來是藍人 第一幕從海裡冒出來
# 到底好看在哪..開頭真的不錯，讓我對這部片抱有期待，結果中間根本在拖，片長這麼長也不好好發揮，淘寶機器人，什麼鬼夜天使，除了讓人看了個尿急，最後轉折堪比最終生還者2外，真的一無所獲，音樂還不錯，但不用看IMAX
# 還以為在看日本片 敘述一堆...最近電影敘述能力比連續劇還遭
# 又長又難看，不建議進戲院，看到一半就想走
# 劇情有點拖，有短暫打瞌睡，動作場面還不錯看，音樂就很好聽了。
# Wakanda Forever No woman no cry.讓我驚豔的是，除了探討人性的刻畫與有深度的劇情轉折， 配樂音效依舊  讓人驚嘆，娛   樂性十足，但視覺特效是唯一美中不足的地方，有些場景很悲慘，不知道是不是因為2D轉3D的關係。總結或許無法達到每個人的標準，但我覺得是今年漫威最好看的電影，8.3/10， Everything's gonna be alright.
# 鋪陳太久導致看的有點悶 期待越大失望越大
# 彩🥚一枚 不用等到片尾結束
# 真的太拖，看得很累，新黑鮑又不太會演
# 不建議去看
# 邊看邊哭，音樂非常好聽！打鬥流暢精彩
# 真的不好看 對於前黑豹的追思很無感 只是拿來消費賺錢的手法 整片格局像是影集一樣 主軸不清 氣勢大大不如第一集 超級敗筆鋼鐵心沒必要出現的角色 人設也不討喜 長得也很醜 裝甲特效根本90年代的動畫卡通 超級出戲 漫威真的在復仇四就該結束
# 還不錯看，情感戲份多了一點，打鬥戲非常精彩，很有意義的一部片
# 好看！個人認為這部是漫威最感人的作品，看完後有些感傷，舒莉這個角色的心路歷程也演的非常的好，很推這部電影
# 盜版阿凡達+印度水行俠+水貨鋼鐵人+骨瘦如柴演技浮誇的女黑豹，就是一部政治正確的電影，演技真的不行，劇情很拖也毫無帶入感，動作設計也遠不如第一集，白白浪費經費在特效上，絕對2022最爛的大作沒有之一
# 跳脫以往漫威爽片格局，還有強烈的反美意識，喜歡超級無腦爽片可能覺得不夠爽，但對於看過全漫威、DC電影的我來說，還蠻滿意的。
# 第一次看到的超悶的漫威動作片！整部戲很拖...女黑豹很弱的感覺！又不太會演！無感的一部片
# 不錯啊，很有意義的片，有騙到我的淚水😌
# 視覺很讚，音樂好聽，情感豐富
#
# 可惜遇到史詩級的電影院雷包
# 打手遊、聊天、脫鞋翹腳抖腳、啃餅乾超大聲
# 直接把腳抬起來跨在前排座位
#
# 現在人電影院都當自己家嗎？？？？
# 一開始很認真看，無奈中、後段廢話對白實在太多，劇情不緊湊，東拼西湊，最後還是睡著了….
# 平心而論是真的好看，但千萬一定要在大螢幕觀賞，因為在自己家裡看的話一定睡著。我很喜歡在弔念第一代黑豹沒有配樂的靜默，但似乎過多到有點煽情，另外黑豹的造型不是說不好，而是有點炫富，要是讓年輕的荷莉·貝瑞來演就完美了。
# 女黑豹是真的好看，打鬥戲是真的有夠精彩
# 光是水裡那首con la brisa歌曲就值五顆星
# 雖然整齣圍繞在前任黑豹-帝查拉病逝的灰暗色系，但劇情架構、配樂、感情面等部分都比起今年的幾部漫威電影更優，片長很長，需要慢慢品味，可以把它當成是一部女黑豹的起源電影來看！
# 好看！沒有冷場
# 音樂很好聽 到後面很感人
# 可以二刷了～～～
# 笑死 那些說不好看的人真不知還有什麼樣的片可以滿足你  黑豹說真的在特效art及整體故事架構的流暢度比這些只會批評別人的鍵盤俠好太多了科科除了這次的主角比較弱以外（畢竟才剛成形）其他真的沒什麼好挑剔了，建議真的要去大螢幕看才會爽
# 這應該是今年最好看的漫威電影....除了溫馨動人..之外..值得去看3D版本
# 電影配樂音樂、服裝很用心，也被王太后的演技驚艷到！
# 蠻好看的，傳達了反戰和思念，都有打動到我。缺點就舒莉太瘦弱了，不能練壯一點嗎...比較像貓女啊
# 明明沒這麼爛，不要垃圾評價給騙了
# 這部不要當商業爽片來看，畫面美到堪稱藝術品，文戲感情演員演的真的很厲害。
# 女將軍跟王后那場真的演超屌
# 鋼鐵心也詮釋的不錯，就莫納的理由跟一些解釋有點攏長，整體真的超過4.5顆心，最近最棒的漫威電影
# 只能說好看啦！！唯一缺點就是妹妹太瘦小了，撐不起黑豹裝。
# 沒那麼爛啦
# 對我來說劇情真的還不錯
# 只是因為本篇較長所以中間交代劇情花了比較多時間
# 阿凡達大戰水行俠
# 看了也不會覺得可惜
# 不看也不會覺得可惜
# 還不錯看~
#
# 年輕女性接手，回歸漫威！..............不能劇透自己去電影院看才有意思！~p.s威漫男英雄退場，由女英雄出頭?這是我最近看威漫的感想！
# （我真的是路人不是什麼花錢的網軍）
# 我是漫威迷 滿心期待進電影院看 不得不說 覺得特效超讚 搭上配樂震撼人心 女性角色很突出 身為女生看了很感動
#
# 但是… 話說的很多 詳細內容解釋很深 動作戲不夠多不夠刺激 我真的看到睡著………..
# 第一次在電影院看漫威電影睡著…🥲🥲🥲
# 恰好的絕無冷場，靜默的滿懷感傷👍👍👍
# 原來是水行俠啊! 我還以為我看的是黑豹..
# ；欸不是，我說主角群本身都已經是黑人了，母女在海邊那幕，有必要那麼暗嗎，真的黑到我什麼都看不到欸(認真
# 漫威近期最爛的片，毫無邏輯只為了政治正確的爛片，建議不要浪費錢，本片花了很多錢買水軍跟網紅，違背良心的大肆宣傳
# 如果只是單純只想看漫威式的動作爽片 那你一定會感到乏味 有一部分原因是現在觀眾胃口被養大了....
# 人性刻畫加以鋪陳 最後再舖出動作打鬥壓軸 這樣才是精彩的點
# 憑心而論  黑鮑真的不好看  大家也是這樣想的吧
# 👍👍👍👍👍👍👍👍👍👍👍
# 沒有到超好看但也不錯了，紀念第一代黑豹超感人！Wakanda Forever
# 很好看很喜歡，情感豐滿，打鬥戲也不差，彩蛋很讚！
# 個人覺得滿好看，有劇情，紀念主角，好像之前紀念玩7保羅沃克一樣概念，有紀念有刺激 覺得值得看
# 近年來最好看的漫威電影，彩蛋真的很可以👍
# 千萬不要相信這麼低的評分，給這麼低分到底有沒有去看啊，本人覺得超級無敵好看，水下國家很有創意，情感部分鋪陳的非常細緻，打鬥也精彩，但如果只是要看打鬥的爽片就真的不適合看～我喜歡看這種多面向圍繞一個主題的精彩電影。
# 習慣看爽片的觀眾可能會失望，但我倒是喜歡這種故事完整性高的劇情，只是女黑豹太像“吱吱”，黑豹裝感覺有點像大頭娃娃‘’頭大身小‘’
# 多說無益看到睡著好險有滑手機睡了兩次而已
# 沒那麼差啦 蠻熱鬧的 還不錯看的片
# 從片頭胃痛到片尾，這部讓我忘了垃圾影集的陰影。
# 這階段真的還好有這部，劇情敘述的很好完全不悶
# 每個角色的演技都開外掛，感覺會是一部得獎電影
# 動作戲也不遜色，納摩的戰鬥方式很爽，但相較於鋼鐵心就沒有像鋼鐵人那麼好看
# 我建議想看一個打一百個的請往刀劍神域走，這部片走的是深度，內心的變化與鬥智，如果你以為這是一部霍元甲or葉問，問兩句你好嗎開打、你昨天好嗎開打、你上測所了嗎開打，想看這類的請往刀劍神域，比較適合心智比較低的小朋友，這部對小朋友來說太難，看完你只會想睡來這留一星，認真建議看心智低的隨時開打刀劍神域
# 這部應該要叫黑貓2，老妹氣勢根本撐不起來，軟趴趴，爛透了。只是想進場懷念查德維克·博斯曼，以及吹冷氣睡覺。抱歉隔壁的情侶，睡到打呼，直到片尾才醒來。
# 接下來週末！ 千萬別選這片
# 千萬別選這片
# 畫面超黑，整片超悶，超難看
# 看了絕對後悔
# 這麼沈悶的電影不能只有我看到，拜託大家趕快花錢去電影院看
# 論爽片不如黑亞當.  但是電影的質感跟劇情轉折勝過黑亞當.
# 本以為我至少會跑一次廁所  沒想到一片到底都很專心看完沒尿遁.
# 這片真的不用花錢去看imax
# 單就第四階段的漫威而言 imax關影體驗差於第四階段的任何一片 ...
# 過於賣弄某些情懷卻又沒有真正打動到內心 導致有些時候無趣的有點令人煩躁
#
# 期待的科技感 或者妹妹繼承後的一些特別之處 都沒有什麼表現
# 水下世界 在播放前的預告阿凡達2的比較下 又顯薄弱
# 雖有些許笑點存在 但與漫威以往風格相比 又少得可憐且無力
#
# 畫面一直過暗 看得是有些辛苦的 問題或許真的不是出在演員身上 而是劇本身上
# 綜觀整體而言 是即便上串流或電視 也不會想二刷的漫威電影
# 第四階段普遍的表現都過差 只能說黑豹2雖然不是墊底的
# 但也覺得就是一個普到不能再普的電影
# 只是為了黑豹3在鋪路罷了 .....
# 民族情，親情，友情，伴隨著復仇演化出戰爭下只有兩造失敗，沒有贏家只有無限仇恨，瓦干達萬歲，但這次我看到真的快睡著，近期英雄片，就以黑亞當論，個人覺得爽度漫威輸DC.
# DC有照顧喜愛爽片的觀眾.
# 近期漫威特效粗糙的問題還是沒有改善，許多場景廉價感十足，臨演感覺是來看熱鬧的，場景切換讓人錯愕，主角撐不起黑豹該有的氣場。
# 總之就是致敬前代黑豹的半套爽片
# 跟黑亞當同樣問題主角演技不足,配角的光芒(命運博士)都搶過主角了,舒莉完全撐不起黑豹反而是納摩還比較有看頭,這部片根本是為了幫納摩鋪路吧
# 漫威娛樂有史以來最難看的電影無誤。遷強.離譜.難以信服的劇情，僅有華麗的配樂還行
# 我覺得舒利算英雄片身材差的
# 整個是紙片人 反而朵拉護衛對身材好多了
# 尤其是娜奇雅
# 只能說舒利只是為了演而演 沒辦法當主角
# 這是一部很Blue 超級英雄電影/主題樂園，整體上的藍色色調搭配納摩新角色對於家鄉海底呈現可能比隔壁棚「水行俠」這家的CGI特效畫面還要唯美以及精緻，都是很符合以「海洋」為主題秋冬旅遊季節，更是一座以海洋生態館為《黑豹2》專門打造的主題遊樂園，內容很多可精彩的動作爽片跟致敬漫畫還原都很適合給小朋友來個最後夏末衝刺~很好看又很好玩
# 沒人可以當黑豹就不要找黑貓來當，真以為拿大便出來都要吃嗎，
# 這種追思會電影不如直接辦一場追思會不是更爽，
# 漫威過氣了，給一星我都嫌虧。
# 今年算是滿難看的電影.....看到打瞌睡
# 我個人覺得是很有劇情的一集. 不是無腦連續打鬥令人厭煩的橋段. 特效的確有待改進的空間, 妹妹撐不太起來, 但是沒人能想到更好的劇情編排來因應鮑斯曼的驟逝.  看著黑豹2.也算是對他最好的緬懷方式, 致上所有欣賞他的影迷最高的敬意
# 真的好好看 片段中弔念黑豹第一代
# 中間也有不一樣的劇情
# 好好哭
# 長達2.5追思會真的很好看
# 我給六顆星這是多的那一顆
# 比多重宇宙好看多了，視覺效果也做得很好
# 黑豹2這樣安排真的很棒了~沒有人會希望查德威克·鮑斯曼就這樣離開了...這一部也算紀念他了~
# 劇情、配樂、畫面都相當優秀，值得一看
# 以為有黑豹，結果沒有，沒有很好👀
# 我覺得很好看，可以二刷，記得帶衛生紙
# 很好看也滿感動的，彩蛋只有一個卻讓人回味無窮，女主角的演技也越來越好，值得二刷
# 剛看完黑亞當再看這部是會有一點落差，但以故事性來講比第一集好看太多，打鬥的爽度也還是有的，看完覺得比第一集好看就是好看啦！
# 黑豹2 片長2小時41分 有夠久的
# 開頭致敬第一代黑豹Wakanda Forever還不錯
# 後來開始說故事跟偶爾穿插小小的打鬥
# 跟反派打鬥的原因很薄弱
# 很像跟預告片阿凡達二的水行種打架
# 後來可想而知~~就是有一顆彩蛋~~
# 可進戲院看也可不進
# 看得出來是第四階段最好的一部(我把蜘蛛人排第二尚氣排第三
# 一直以來對於神作的續集都有點戒心
# 沒想到Wakanda Forever令人驚艷， 爆炸好看
# 只想看爽片的人你會失望
# ---下面評論微有雷----
# 故事的深度個人覺得超越第一集
# 導演本來就是黑豹的好朋友
# 在查德威過世後怎麼走過傷痛，把這個角色的精神洗煉純化後帶給角色生命
# 成了第二集重要的元素
# 故事也在探討『超凡力量』這個議題
# 第一集裡面，力量的象徵汎合金，先是從掩藏（黑豹父親）-->藏不住(黑豹的課題)而進到-->有限度地與世人共享（成立瓦干達交流中心）
# 第二集則繼續述說，『你』，『瓦干達』並不是超凡力量唯一的唯一繼承者呢？如果過去覺得你很強，但現在來了一個跟你一樣強、甚至更強的『對手』，並且帶來威脅....你還能遵守德性與仁義嗎？你想控制『力量』，會不會其實這個執念裡，自己成了被奴役的一方？ 這部分有非常精彩的探討。
# 再來是親情的刻畫，Suri既是公主，也是黑豹的妹妹，王后的女兒...面對外有敵，內有傷痛的夾殺，要怎麼蛻變出來？ 個人對於失去手足的情節因為有經驗，所以非常讚賞電影的敘事與刻劃，人生的深度是要在深谷與高峰間親自走過，才能被淬煉出來。
# 結論是，好的故事會講光明如何戰勝黑暗，而優秀的故事，則講述的黑暗與光明如何被帶回無極。
# 這是2022年的Wakanda Forever, 今年進影院最超值的一次

# %%
# 若是這一段程式碼 輸出只有第八頁的資料
    
# lst = soup.find_all('form', class_='form_good')


#     for x in lst:
    
#         comment = x.find_all('span')
    
#         for y in comment:
        
#             comment2 = y.text
#     print(comment2)

# %%
sf = pd.DataFrame(temp)

# %%
sf
# Out:
#                                                     0
# 0                          舒莉有點太瘦，沒有美隊的強壯感\r\n但劇情上還不錯
# 1   樓下說黑亞當贏過黑豹2 我聽你放屁 (黑亞當後面我看到睡著 老套的美式超人主義 亂七八糟的特...
# 2   整體體感黑亞當>黑豹2>奇異博士2>=雷神4但如果只比劇情的話黑豹2>黑亞當;其實黑豹2太攏...
# 3   劇情硬湊連貫的不合理，主角的心路歷程難引起共鳴，整部作品只是為了延續商品價值而硬湊端上的菜色...
# 4   根據外媒報導，黑豹2的劇本在男主角查德維克.博斯曼過世後,導演和編劇重新翻新改寫,讓舒莉來承...
# ..                                                ...
# 95            很好看也滿感動的，彩蛋只有一個卻讓人回味無窮，女主角的演技也越來越好，值得二刷
# 96  剛看完黑亞當再看這部是會有一點落差，但以故事性來講比第一集好看太多，打鬥的爽度也還是有的，看...
# 97  黑豹2 片長2小時41分 有夠久的\r\n開頭致敬第一代黑豹Wakanda Forever還...
# 98                       看得出來是第四階段最好的一部(我把蜘蛛人排第二尚氣排第三
# 99  一直以來對於神作的續集都有點戒心\r\n沒想到Wakanda Forever令人驚艷， 爆炸...
#
# [100 rows x 1 columns]

# %%
sf.shape
# Out:
# (100, 1)

# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
from collections import Counter

# %%
sf['seg'] = ""
sf.head()
# Out:
#                                                    0 seg
# 0                         舒莉有點太瘦，沒有美隊的強壯感\r\n但劇情上還不錯
# 1  樓下說黑亞當贏過黑豹2 我聽你放屁 (黑亞當後面我看到睡著 老套的美式超人主義 亂七八糟的特...
# 2  整體體感黑亞當>黑豹2>奇異博士2>=雷神4但如果只比劇情的話黑豹2>黑亞當;其實黑豹2太攏...
# 3  劇情硬湊連貫的不合理，主角的心路歷程難引起共鳴，整部作品只是為了延續商品價值而硬湊端上的菜色...
# 4  根據外媒報導，黑豹2的劇本在男主角查德維克.博斯曼過世後,導演和編劇重新翻新改寫,讓舒莉來承...

# %%
jieba.load_userdict('userdict.txt')

# %%
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
for documents in sf[0]:
    seg_list = jieba.analyse.extract_tags(documents, 100)
    #seg_list = jieba.lcut(documents)
    sf['seg'].iloc[index] = seg_list
    index += 1

# %%
sf['seg']
# Out:
# 0                        [舒莉, 沒有, 美隊, 強壯感, 但劇, 情上, 還不錯]
# 1     [黑豹, 喜感, 阿凡, 瑕不掩瑜, 樓下, 黑亞當, 贏過, 黑亞, 當後面, 睡著, 主...
# 2     [黑豹, 整體, 黑亞當, 體感, 奇異, 比劇情, 太攏, 不夠, 湊動作, 戲太少, 緊...
# 3     [心路, 劇情, 連貫, 歷程, 共鳴, 延續, 價值, 湊端, 菜色, 整部, 好吃, 主...
# 4     [黑豹, 女配角, 本片, 外媒, 報導, 劇本, 維克, 博斯曼, 過世, 導演, 編劇,...
#                             ...
# 95        [感動, 彩蛋, 一個, 無窮, 二刷, 演技, 女主角, 回味, 好看, 值得, 只有]
# 96    [第一集, 好看, 剛看, 黑亞當, 這部, 一點, 講比, 打鬥, 爽度, 完覺, 故事性...
# 97    [打鬥, 黑豹, 阿凡, 反派, 片長, 小時, 41, 有夠, 開頭, Wakanda, ...
# 98                  [蜘蛛人, 尚氣排, 看得出, 第四, 一部, 第三, 最好, 第二]
# 99    [黑豹, 第二集, 故事, Wakanda, Forever, 傷痛, 探討, --, 瓦干...
# Name: seg, Length: 100, dtype: object

# %%
subdata_seg_list = sf['seg'].tolist()

# %%
subdata_seg_list
# Out:
# [['舒莉', '沒有', '美隊', '強壯感', '但劇', '情上', '還不錯'],
#  ['黑豹',
#   '喜感',
#   '阿凡',
#   '瑕不掩瑜',
#   '樓下',
#   '黑亞當',
#   '贏過',
#   '黑亞',
#   '當後面',
#   '睡著',
#   '主義',
#   '這部',
#   '一樣',
#   '承襲',
#   '宏偉',
#   '每個',
#   '刻劃',
#   '不會輕',
#   '描淡',
#   '畫面',
#   '一個',
#   '國家',
#   '水行俠',
#   'FU',
#   '老套',
#   '美中不足',
#   '超人',
#   '美式',
#   '特效',
#   '很漂亮',
#   '看到',
#   '七八',
#   '放屁',
#   '女生',
#   '角色',
#   '清楚',
#   '精神',
#   '世界',
#   '就是'],
#  ['黑豹',
#   '整體',
#   '黑亞當',
#   '體感',
#   '奇異',
#   '比劇情',
#   '太攏',
#   '不夠',
#   '湊動作',
#   '戲太少',
#   '緊張',
#   '不會',
#   '來覺',
#   '電影',
#   '我個',
#   '人覺',
#   '下來',
#   '漫威',
#   '贏過',
#   'DC',
#   '雷神',
#   '博士',
#   '缺少',
#   '看出',
#   '一片',
#   '今年',
#   '所以',
#   '如果'],
#  ['心路',
#   '劇情',
#   '連貫',
#   '歷程',
#   '共鳴',
#   '延續',
#   '價值',
#   '湊端',
#   '菜色',
#   '整部',
#   '好吃',
#   '主角',
#   '不合理',
#   '作品',
#   '商品',
#   '引起',
#   '只是',
#   '可能'],
#  ['黑豹',
#   '女配角',
#   '本片',
#   '外媒',
#   '報導',
#   '劇本',
#   '維克',
#   '博斯曼',
#   '過世',
#   '導演',
#   '編劇',
#   '改寫',
#   '舒莉來',
#   '實在',
#   '服觀眾',
#   '舒莉',
#   '感覺',
#   '演貓',
#   '......',
#   '演拉瑪達',
#   '安琪拉',
#   '貝瑟',
#   'Angela',
#   'Bassett',
#   '準備',
#   '入圍',
#   '奧斯卡',
#   '查德',
#   '男主角',
#   '翻新',
#   '提名',
#   '薄弱',
#   '承接',
#   '精彩',
#   '身分',
#   '角色',
#   '表演',
#   '皇后',
#   '重新',
#   '可以'],
#  ['阿凡',
#   '我個',
#   '覺得',
#   '滿有',
#   '略帶',
#   '不過',
#   '有悶',
#   '第一集',
#   '好看',
#   '影子',
#   '深度',
#   '部分',
#   '一些'],
#  ['橋段',
#   '不太能',
#   '這部',
#   '心戲',
#   '還不錯',
#   '邏輯',
#   '上實',
#   '相當',
#   '厲害',
#   '勉強',
#   '整體',
#   '緬懷',
#   'Chadwick',
#   'Aaron',
#   'Boseman',
#   '演得',
#   '整部',
#   '演技',
#   '女主角',
#   '挑起',
#   '女王',
#   '粗糙',
#   '主角',
#   '肌肉',
#   '可惜',
#   '令人',
#   '理解',
#   '而言',
#   '某些',
#   '集中',
#   '部分',
#   '一些',
#   '主要'],
#  ['很難', '最難', '漫威', '別騙', '系列'],
#  ['睡著', '五顆', '通通', '沙丘', '其它', '所有', '只有'],
#  ['演起', '感覺', '靈魂', '素人', '演戲', '女主角', '小女孩', '像是', '故事'],
#  ['舒莉', '沒有', '美隊', '強壯感', '但劇', '情上', '還不錯'],
#  ['黑豹',
#   '喜感',
#   '阿凡',
#   '瑕不掩瑜',
#   '樓下',
#   '黑亞當',
#   '贏過',
#   '黑亞',
#   '當後面',
#   '睡著',
#   '主義',
#   '這部',
#   '一樣',
#   '承襲',
#   '宏偉',
#   '每個',
#   '刻劃',
#   '不會輕',
#   '描淡',
#   '畫面',
#   '一個',
#   '國家',
#   '水行俠',
#   'FU',
#   '老套',
#   '美中不足',
#   '超人',
#   '美式',
#   '特效',
#   '很漂亮',
#   '看到',
#   '七八',
#   '放屁',
#   '女生',
#   '角色',
#   '清楚',
#   '精神',
#   '世界',
#   '就是'],
#  ['黑豹',
#   '整體',
#   '黑亞當',
#   '體感',
#   '奇異',
#   '比劇情',
#   '太攏',
#   '不夠',
#   '湊動作',
#   '戲太少',
#   '緊張',
#   '不會',
#   '來覺',
#   '電影',
#   '我個',
#   '人覺',
#   '下來',
#   '漫威',
#   '贏過',
#   'DC',
#   '雷神',
#   '博士',
#   '缺少',
#   '看出',
#   '一片',
#   '今年',
#   '所以',
#   '如果'],
#  ['心路',
#   '劇情',
#   '連貫',
#   '歷程',
#   '共鳴',
#   '延續',
#   '價值',
#   '湊端',
#   '菜色',
#   '整部',
#   '好吃',
#   '主角',
#   '不合理',
#   '作品',
#   '商品',
#   '引起',
#   '只是',
#   '可能'],
#  ['黑豹',
#   '女配角',
#   '本片',
#   '外媒',
#   '報導',
#   '劇本',
#   '維克',
#   '博斯曼',
#   '過世',
#   '導演',
#   '編劇',
#   '改寫',
#   '舒莉來',
#   '實在',
#   '服觀眾',
#   '舒莉',
#   '感覺',
#   '演貓',
#   '......',
#   '演拉瑪達',
#   '安琪拉',
#   '貝瑟',
#   'Angela',
#   'Bassett',
#   '準備',
#   '入圍',
#   '奧斯卡',
#   '查德',
#   '男主角',
#   '翻新',
#   '提名',
#   '薄弱',
#   '承接',
#   '精彩',
#   '身分',
#   '角色',
#   '表演',
#   '皇后',
#   '重新',
#   '可以'],
#  ['阿凡',
#   '我個',
#   '覺得',
#   '滿有',
#   '略帶',
#   '不過',
#   '有悶',
#   '第一集',
#   '好看',
#   '影子',
#   '深度',
#   '部分',
#   '一些'],
#  ['橋段',
#   '不太能',
#   '這部',
#   '心戲',
#   '還不錯',
#   '邏輯',
#   '上實',
#   '相當',
#   '厲害',
#   '勉強',
#   '整體',
#   '緬懷',
#   'Chadwick',
#   'Aaron',
#   'Boseman',
#   '演得',
#   '整部',
#   '演技',
#   '女主角',
#   '挑起',
#   '女王',
#   '粗糙',
#   '主角',
#   '肌肉',
#   '可惜',
#   '令人',
#   '理解',
#   '而言',
#   '某些',
#   '集中',
#   '部分',
#   '一些',
#   '主要'],
#  ['很難', '最難', '漫威', '別騙', '系列'],
#  ['睡著', '五顆', '通通', '沙丘', '其它', '所有', '只有'],
#  ['演起', '感覺', '靈魂', '素人', '演戲', '女主角', '小女孩', '像是', '故事'],
#  ['比奇', '劇情', '笑點', '哭點', '雷神', '好看', '博士'],
#  ['推薦',
#   '到後來',
#   '過世',
#   '雖然',
#   '覺得',
#   '有點長',
#   '成的還',
#   '但後面',
#   '變成',
#   '敵人',
#   '還有',
#   '研發',
#   '出類',
#   '鋼鐵人',
#   '這點',
#   '黑豹',
#   '挺身而出',
#   '草率',
#   '小女孩',
#   '解救',
#   '打到',
#   '高科技',
#   '公主',
#   '前面',
#   '故事',
#   '接受',
#   '如何',
#   '部分',
#   '一定',
#   '以及',
#   '不能',
#   '可以'],
#  ['黑豹',
#   '漫威',
#   '這部',
#   '緊張',
#   '感覺',
#   '爽度',
#   '滿頭',
#   '問好',
#   '身為',
#   '一個',
#   '最強',
#   '之國',
#   '太不經',
#   '動不動',
#   '當菜',
#   '......',
#   '上映',
#   '好看',
#   '缺少',
#   '入侵',
#   '基本上',
#   '以外',
#   '刺激',
#   '除了',
#   '地方',
#   '世界',
#   '一定',
#   '就是'],
#  ['阿凡',
#   '顏值',
#   '最爛',
#   '東湊',
#   '西湊',
#   '劇情',
#   '好爛',
#   '盜版',
#   '鋼鐵人',
#   '水行俠',
#   '還好',
#   '音樂',
#   '還算',
#   '特效',
#   '描述',
#   '一部',
#   '可以'],
#  ['阿凡', '最酷', '羽蛇神', '藍人', '從海裡', '出來', '全片', '第一幕', '影子', '只有'],
#  ['..',
#   '開頭',
#   '不錯',
#   '這部片',
#   '結果',
#   '中間',
#   '片長',
#   '這麼',
#   '發揮',
#   '淘寶機器',
#   '什麼',
#   '鬼夜',
#   '最後轉',
#   '折堪',
#   '終生',
#   '還者',
#   '一無所',
#   '音樂',
#   '還不錯',
#   'IMAX',
#   '尿急',
#   '天使',
#   '好看',
#   '期待',
#   '好好',
#   '不用',
#   '到底',
#   '根本',
#   '除了'],
#  ['敘述', '還以', '...', '電影', '比連續劇', '還遭', '一堆', '最近', '日本', '能力'],
#  ['不建議', '進戲院', '一半', '看到'],
#  ['劇情', '動作', '場面', '還不錯', '音樂', '打瞌睡'],
#  ['音效',
#   'Wakanda',
#   'Forever',
#   'No',
#   'woman',
#   'no',
#   'cry',
#   '探討',
#   '刻畫',
#   '劇情',
#   '轉折',
#   '配樂',
#   '依舊',
#   '驚嘆',
#   '樂性',
#   '但視覺',
#   '場景',
#   '悲慘',
#   '因為',
#   '2D',
#   '3D',
#   '的關',
#   '總結',
#   '許無法',
#   '每個',
#   '標準',
#   '覺得',
#   '漫威',
#   '電影',
#   '8.3',
#   '10',
#   'Everything',
#   'gonna',
#   'alright',
#   '美中不足',
#   '特效',
#   '人性',
#   '十足',
#   '好看',
#   '深度',
#   '唯一',
#   '是不是',
#   '除了',
#   '有些',
#   '地方',
#   '今年',
#   '知道'],
#  ['越大', '導致', '點悶', '片尾', '結束', '太久', '一枚', '失望', '期待', '等到', '不用'],
#  ['不太會演', '不建議'],
#  ['邊看', '邊哭', '音樂', '打鬥', '流暢', '精彩', '非常'],
#  ['超級',
#   '影集',
#   '很無感',
#   '拿來',
#   '消費',
#   '一樣',
#   '主軸不清',
#   '氣勢',
#   '敗筆',
#   '鋼鐵心',
#   '出現',
#   '人設',
#   '討喜',
#   '很醜',
#   '裝甲',
#   '90',
#   '動畫',
#   '出戲',
#   '漫威',
#   '結束',
#   '第一集',
#   '整片',
#   '黑豹',
#   '追思',
#   '卡通',
#   '特效',
#   '好看',
#   '手法',
#   '角色',
#   '大大',
#   '像是',
#   '不如',
#   '格局',
#   '必要',
#   '根本',
#   '年代',
#   '只是'],
#  ['還不錯', '戲份', '一點', '打鬥戲', '義的', '精彩', '情感', '有意', '一部', '非常'],
#  ['這部',
#   '心路',
#   '認為',
#   '漫威',
#   '感傷',
#   '舒莉',
#   '歷程',
#   '電影',
#   '感人',
#   '好看',
#   '角色',
#   '作品',
#   '非常',
#   '有些'],
#  ['演技',
#   '阿凡',
#   '盜版',
#   '水行俠',
#   '水貨',
#   '鋼鐵人',
#   '浮誇',
#   '正確',
#   '電影',
#   '劇情',
#   '毫無帶',
#   '入感',
#   '動作',
#   '設計',
#   '費經費',
#   '絕對',
#   '2022',
#   '最爛',
#   '沒有',
#   '第一集',
#   '黑豹',
#   '骨瘦如柴',
#   '特效',
#   '白浪',
#   '大作',
#   '一部',
#   '不行',
#   '不如',
#   '印度',
#   '政治',
#   '之一',
#   '就是'],
#  ['爽片',
#   '跳脫',
#   '漫威',
#   '還有',
#   '強烈',
#   '喜歡',
#   '超級',
#   '無腦',
#   '覺得',
#   '不夠',
#   '看過',
#   '全漫威',
#   'DC',
#   '電影',
#   '還蠻',
#   '滿意',
#   '美意',
#   '以往',
#   '格局',
#   '可能'],
#  ['超悶',
#   '漫威動',
#   '作片',
#   '戲很拖',
#   '...',
#   '感覺',
#   '不太會演',
#   '無感',
#   '黑豹',
#   '整部',
#   '很弱',
#   '一部',
#   '第一次',
#   '看到'],
#  ['不錯', '義的片', '淚水', '有意'],
#  ['影院',
#   '視覺',
#   '音樂',
#   '豐富',
#   '史詩級',
#   '的電',
#   '雷包',
#   '脫鞋',
#   '腳抖',
#   '餅乾',
#   '現在',
#   '人電',
#   '都當',
#   '排座位',
#   '打手',
#   '超大',
#   '聊天',
#   '情感',
#   '抬起',
#   '可惜',
#   '遇到',
#   '直接',
#   '自己'],
#  ['一開始', '認真', '無奈中', '廢話', '白實', '劇情', '不緊', '東拼西', '最後還'],
#  ['黑豹',
#   '平心',
#   '而論',
#   '但千萬',
#   '螢幕',
#   '觀賞',
#   '因為',
#   '家裡',
#   '睡著',
#   '喜歡',
#   '沒有',
#   '配樂',
#   '靜默',
#   '過多到',
#   '炫富',
#   '荷莉',
#   '貝瑞來',
#   '煽情',
#   '第一代',
#   '一定',
#   '好看',
#   '完美',
#   '造型',
#   '要是',
#   '不好',
#   '似乎',
#   '而是',
#   '另外',
#   '不是',
#   '自己'],
#  ['打鬥戲', '有夠', '黑豹', '精彩', '好看'],
#  ['水裡', 'con', 'la', 'brisa', '就值', '五顆', '那首', '光是', '歌曲'],
#  ['黑豹',
#   '雖然整',
#   '圍繞',
#   '但劇',
#   '情架構',
#   '配樂',
#   '面等',
#   '幾部',
#   '漫威',
#   '電影',
#   '片長',
#   '很長',
#   '當成',
#   '電影來',
#   '查拉',
#   '色系',
#   '灰暗',
#   '品味',
#   '前任',
#   '病逝',
#   '比起',
#   '起源',
#   '一部',
#   '感情',
#   '慢慢',
#   '部分',
#   '需要',
#   '今年',
#   '可以'],
#  ['沒有', '冷場', '音樂', '到後面', '二刷', '感人', '好看', '可以'],
#  ['還有',
#   '什麼樣',
#   '滿足',
#   'art',
#   '整體',
#   '架構',
#   '暢度',
#   '這些',
#   '只會批',
#   '評別',
#   '盤俠',
#   '科科',
#   '這次',
#   '比較',
#   '畢竟',
#   '才剛',
#   '沒什麼',
#   '建議',
#   '螢幕',
#   '會爽',
#   '黑豹',
#   '特效',
#   '挑剔',
#   '成形',
#   '主角',
#   '好看',
#   '以外',
#   '故事',
#   '除了',
#   '不知',
#   '那些',
#   '其他',
#   '可以'],
#  ['..', '這應', '漫威', '電影', '....', '溫馨動', 'D版', '好看', '值得', '之外', '除了', '今年'],
#  ['王太后', '電影', '配樂', '音樂', '服裝', '驚艷到', '演技', '用心'],
#  ['傳達',
#   '反戰',
#   '打動',
#   '缺點',
#   '舒莉',
#   '練壯',
#   '一點',
#   '...',
#   '比較',
#   '貓女',
#   '瘦弱',
#   '思念',
#   '好看',
#   '不能'],
#  ['這麼爛',
#   '評價給',
#   '這部',
#   '當商業',
#   '爽片',
#   '畫面',
#   '美到',
#   '堪稱',
#   '藝術品',
#   '文戲',
#   '演員演',
#   '厲害',
#   '女將',
#   '那場',
#   '演超',
#   '鋼鐵心',
#   '詮釋',
#   '不錯',
#   '莫納',
#   '解釋',
#   '整體',
#   '超過',
#   '4.5',
#   '顆心',
#   '最棒',
#   '漫威',
#   '電影',
#   '不要',
#   '王后',
#   '垃圾',
#   '明明',
#   '感情',
#   '理由',
#   '最近',
#   '一些'],
#  ['缺點', '不起', '黑豹', '瘦小', '好看', '妹妹', '唯一', '只能', '就是'],
#  ['劇情', '那麼爛', '還不錯', '因為', '較長', '中間', '時間', '本篇', '交代', '只是', '所以'],
#  ['不會', '覺得', '阿凡', '可惜', '達大戰', '水行俠', '不看'],
#  ['還不錯',
#   '年輕',
#   '回歸漫威',
#   '..............',
#   '劇透',
#   '去電',
#   '看才',
#   '威漫',
#   '退場',
#   '出頭',
#   '這是',
#   '看威漫',
#   '女英雄',
#   '感想',
#   '影院',
#   '接手',
#   '有意思',
#   '英雄',
#   '女性',
#   '最近',
#   '不能',
#   '自己'],
#  ['不夠',
#   '影院',
#   '什麼',
#   '錢的網',
#   '漫威迷',
#   '滿心',
#   '進電',
#   '覺得',
#   '配樂',
#   '身為',
#   '感動',
#   '詳細',
#   '內容',
#   '解釋',
#   '動作戲',
#   '睡著',
#   '..',
#   '在電',
#   '看漫威',
#   '電影',
#   '震撼人心',
#   '特效',
#   '搭上',
#   '女生',
#   '角色',
#   '期待',
#   '女性',
#   '不得不',
#   '突出',
#   '第一次',
#   '刺激',
#   '看到',
#   '很多',
#   '但是',
#   '不是'],
#  ['絕無冷場', '靜默', '滿懷', '感傷', '恰好'],
#  ['原來',
#   '水行俠',
#   '還以',
#   '..',
#   '已經',
#   '海邊',
#   '那幕',
#   '那麼',
#   '黑到',
#   '什麼',
#   '認真',
#   '黑豹',
#   '母女',
#   '主角',
#   '黑人',
#   '看不到',
#   '必要',
#   '本身',
#   '不是'],
#  ['本片',
#   '漫威',
#   '最爛',
#   '毫無邏輯',
#   '正確',
#   '爛片',
#   '建議',
#   '浪費',
#   '網紅',
#   '違背',
#   '宣傳',
#   '良心',
#   '大肆',
#   '近期',
#   '政治',
#   '不要',
#   '很多'],
#  ['單純',
#   '漫威式',
#   '動作',
#   '爽片',
#   '現在',
#   '觀眾',
#   '養大',
#   '....',
#   '刻畫',
#   '最後再',
#   '出動作',
#   '打鬥',
#   '壓軸',
#   '這樣',
#   '的點',
#   '乏味',
#   '胃口',
#   '人性',
#   '精彩',
#   '加以',
#   '一部分',
#   '感到',
#   '原因',
#   '只是',
#   '一定',
#   '如果'],
#  ['憑心', '而論', '這樣', '好看', '大家'],
#  [],
#  ['沒有', '不錯', '紀念', 'Wakanda', 'Forever', '黑豹', '感人', '第一代', '好看'],
#  ['喜歡', '豐滿', '打鬥戲', '彩蛋', '不差', '好看', '情感'],
#  ['紀念',
#   '人覺',
#   '劇情',
#   '保羅沃克',
#   '一樣',
#   '有紀念',
#   '覺得',
#   '主角',
#   '好看',
#   '值得',
#   '概念',
#   '好像',
#   '刺激',
#   '之前'],
#  ['漫威', '電影', '彩蛋', '近年', '好看', '可以'],
#  ['打鬥',
#   '精彩',
#   '低分',
#   '千萬',
#   '這麼',
#   '評分',
#   '給這麼',
#   '覺得',
#   '超級',
#   '無敵',
#   '國家',
#   '創意',
#   '爽片',
#   '適合',
#   '喜歡',
#   '這種',
#   '圍繞',
#   '一個',
#   '主題',
#   '電影',
#   '好看',
#   '面向',
#   '情感',
#   '水下',
#   '本人',
#   '到底',
#   '相信',
#   '非常',
#   '不要',
#   '部分',
#   '只是',
#   '如果'],
#  ['黑豹',
#   '習慣',
#   '爽片',
#   '觀眾',
#   '喜歡',
#   '這種',
#   '劇情',
#   '太像',
#   '裝感覺',
#   '大頭',
#   '頭大身',
#   '吱吱',
#   '完整性',
#   '娃娃',
#   '失望',
#   '故事',
#   '只是',
#   '可能'],
#  ['無益', '睡著', '好險', '手機', '兩次', '而已', '看到'],
#  ['那麼', '蠻熱鬧', '還不錯'],
#  ['影集', '從片頭', '片尾', '這部', '陰影', '胃痛', '垃圾'],
#  ['很爽',
#   '這階段',
#   '還好',
#   '這部',
#   '劇情',
#   '敘述',
#   '不悶',
#   '每個',
#   '開外掛',
#   '感覺',
#   '得獎',
#   '電影',
#   '動作戲',
#   '不遜色',
#   '納摩',
#   '戰鬥',
#   '相較',
#   '鋼鐵心',
#   '鋼鐵人',
#   '那麼',
#   '演技',
#   '好看',
#   '角色',
#   '一部',
#   '完全',
#   '方式'],
#  ['神域',
#   '比較',
#   '心智',
#   '小朋友',
#   '霍元甲',
#   '我建議',
#   '一個',
#   '這部片',
#   '內心',
#   '變化',
#   '鬥智',
#   '這是',
#   '葉問',
#   '問兩句',
#   '上測',
#   '這類',
#   '適合',
#   '這部',
#   '太難',
#   '只會',
#   '睡來',
#   '這留',
#   '認真',
#   '建議',
#   '隨時',
#   '打刀',
#   '一星',
#   '一百',
#   '你好',
#   '深度',
#   '一部',
#   '昨天',
#   '如果'],
#  ['打呼',
#   '這部',
#   '應該',
#   '黑貓',
#   '老妹',
#   '氣勢',
#   '起來',
#   '爛透',
#   '進場',
#   '懷念',
#   '維克',
#   '博斯曼',
#   '冷氣',
#   '睡覺',
#   '情侶',
#   '片尾',
#   '查德',
#   '抱歉',
#   '隔壁',
#   '直到',
#   '根本',
#   '只是',
#   '以及'],
#  ['千萬別', '這片', '週末', '畫面', '超黑', '超悶', '超難', '絕對後悔', '整片', '接下'],
#  ['這麼', '沈悶', '電影', '趕快', '花錢', '去電', '影院', '大家', '看到', '只有', '不能'],
#  ['黑亞當',
#   '本以',
#   '論爽片',
#   '電影',
#   '質感',
#   '劇情',
#   '轉折',
#   '勝過',
#   '廁所',
#   '專心',
#   '沒尿遁',
#   '不如',
#   '至少',
#   '到底',
#   '想到',
#   '一片',
#   '一次',
#   '但是'],
#  ['漫威',
#   'imax',
#   '表現',
#   '電影',
#   '黑豹',
#   '第四',
#   '有些',
#   '阿凡',
#   '這片',
#   '花錢',
#   '關影',
#   '體驗',
#   '...',
#   '過於賣',
#   '情懷',
#   '打動',
#   '內心',
#   '導致',
#   '時候',
#   '無趣',
#   '煩躁',
#   '繼承',
#   '特別',
#   '之處',
#   '什麼',
#   '預告',
#   '許笑點',
#   '風格',
#   '可憐且',
#   '無力',
#   '畫面',
#   '過暗',
#   '問題',
#   '或許',
#   '演員',
#   '綜觀',
#   '整體',
#   '串流',
#   '電視',
#   '不會',
#   '想二刷',
#   '過差',
#   '雖然',
#   '墊底',
#   '覺得',
#   '一個',
#   '普到',
#   '再普',
#   '路罷',
#   '.....',
#   '而言',
#   '少得',
#   '播放',
#   '薄弱',
#   '不是',
#   '辛苦',
#   '水下',
#   '妹妹',
#   '期待',
#   '以往',
#   '即便',
#   '令人',
#   '不用',
#   '科技',
#   '某些',
#   '本身',
#   '相比',
#   '一片',
#   '普遍',
#   '身上',
#   '真正',
#   '只能',
#   '或者',
#   '而是',
#   '任何',
#   '存在',
#   '一直',
#   '只是',
#   '世界',
#   '一些',
#   '不能',
#   '就是'],
#  ['DC',
#   '民族情',
#   '親情',
#   '隨著',
#   '戰爭',
#   '兩造',
#   '失敗',
#   '沒有',
#   '贏家',
#   '無限',
#   '瓦干達',
#   '萬歲',
#   '這次',
#   '黑亞',
#   '當論',
#   '人覺',
#   '爽度',
#   '漫威輸',
#   '有照',
#   '顧喜',
#   '愛爽片',
#   '觀眾',
#   '演化出',
#   '友情',
#   '只有',
#   '仇恨',
#   '英雄',
#   '近期',
#   '看到'],
#  ['黑豹',
#   '半套',
#   '漫威',
#   '問題',
#   '沒有',
#   '許多場',
#   '景廉',
#   '價感',
#   '臨演',
#   '感覺',
#   '熱鬧',
#   '場景',
#   '切換',
#   '人錯',
#   '不起',
#   '氣場',
#   '爽片',
#   '特效',
#   '致敬',
#   '十足',
#   '粗糙',
#   '主角',
#   '改善',
#   '近期',
#   '就是'],
#  ['主角',
#   '黑亞當',
#   '同樣',
#   '問題',
#   '命運',
#   '搶過',
#   '舒莉',
#   '不起',
#   '納摩',
#   '還比',
#   '看頭',
#   '這部片',
#   '幫納摩鋪',
#   '黑豹',
#   '配角',
#   '演技',
#   '光芒',
#   '博士',
#   '反而',
#   '不足',
#   '根本',
#   '完全'],
#  ['漫威',
#   '娛樂',
#   '有史',
#   '以來',
#   '最難',
#   '電影',
#   '無誤',
#   '遷強',
#   '離譜',
#   '難以',
#   '劇情',
#   '僅有',
#   '華麗',
#   '配樂',
#   '還行',
#   '信服'],
#  ['舒利',
#   '身材',
#   '我覺',
#   '整個',
#   '紙片',
#   '拉護衛',
#   '奇雅',
#   '演而演',
#   '沒辦',
#   '法當',
#   '主角',
#   '好多',
#   '英雄',
#   '反而',
#   '只能',
#   '尤其',
#   '只是'],
#  ['主題',
#   '海洋',
#   '這是',
#   'Blue',
#   '超級',
#   '電影',
#   '樂園',
#   '整體',
#   '藍色色',
#   '納摩新',
#   '呈現',
#   '水行俠',
#   '這家',
#   'CGI',
#   '畫面',
#   '還要',
#   '為主題',
#   '旅遊',
#   '季節',
#   '生態館',
#   '專門',
#   '遊樂園',
#   '內容',
#   '動作',
#   '爽片',
#   '漫畫',
#   '還原',
#   '適合給',
#   '來個',
#   '衝刺',
#   '夏末',
#   '黑豹',
#   '唯美',
#   '小朋友',
#   '特效',
#   '致敬',
#   '秋冬',
#   '好玩',
#   '隔壁',
#   '搭配',
#   '精彩',
#   '好看',
#   '打造',
#   '海底',
#   '角色',
#   '英雄',
#   '一部',
#   '符合',
#   '一座',
#   '更是',
#   '很多',
#   '以及',
#   '可能'],
#  ['追思',
#   '沒人',
#   '黑貓',
#   '來當',
#   '真以',
#   '出來',
#   '這種',
#   '會電影',
#   '辦一場',
#   '更爽',
#   '漫威',
#   '過氣',
#   '給一星',
#   '黑豹',
#   '大便',
#   '不如',
#   '不要',
#   '直接',
#   '不是',
#   '可以'],
#  ['滿難', '電影', '.....', '打瞌睡', '算是', '看到', '今年'],
#  ['劇情',
#   '我個',
#   '人覺',
#   '無腦',
#   '連續',
#   '打鬥',
#   '厭煩',
#   '橋段',
#   '的確',
#   '改進',
#   '空間',
#   '不太起',
#   '沒人能',
#   '編排',
#   '因應',
#   '鮑斯曼',
#   '驟逝',
#   '看著',
#   '緬懷',
#   '致上',
#   '欣賞',
#   '一集',
#   '黑豹',
#   '影迷',
#   '特效',
#   '敬意',
#   '有待',
#   '妹妹',
#   '算是',
#   '更好',
#   '令人',
#   '最好',
#   '想到',
#   '最高',
#   '方式',
#   '所有',
#   '但是',
#   '不是'],
#  ['中間', '一樣', '劇情', '好好看', '黑豹', '片段', '第一代', '好好'],
#  ['2.5', '我給', '六顆', '這是', '一顆', '追思', '好看'],
#  ['視覺', '多重', '好看', '宇宙', '效果'],
#  ['這樣', '鮑斯曼', '離開', '...', '算紀念', '查德威', '很棒', '黑豹', '一部', '安排', '希望', '有人'],
#  ['劇情', '配樂', '畫面', '相當', '優秀', '值得一看'],
#  ['沒有', '以為', '結果', '黑豹'],
#  ['我覺', '二刷', '記得', '帶衛', '生紙', '好看', '可以'],
#  ['感動', '彩蛋', '一個', '無窮', '二刷', '演技', '女主角', '回味', '好看', '值得', '只有'],
#  ['第一集',
#   '好看',
#   '剛看',
#   '黑亞當',
#   '這部',
#   '一點',
#   '講比',
#   '打鬥',
#   '爽度',
#   '完覺',
#   '故事性',
#   '落差',
#   '就是'],
#  ['打鬥',
#   '黑豹',
#   '阿凡',
#   '反派',
#   '片長',
#   '小時',
#   '41',
#   '有夠',
#   '開頭',
#   'Wakanda',
#   'Forever',
#   '還不錯',
#   '開始',
#   '偶爾',
#   '預告片',
#   '水行種',
#   '一顆',
#   '彩蛋',
#   '可進',
#   '戲院',
#   '致敬',
#   '穿插',
#   '可想而知',
#   '第一代',
#   '打架',
#   '薄弱',
#   '可不',
#   '小小的',
#   '故事',
#   '原因',
#   '就是'],
#  ['蜘蛛人', '尚氣排', '看得出', '第四', '一部', '第三', '最好', '第二'],
#  ['黑豹',
#   '第二集',
#   '故事',
#   'Wakanda',
#   'Forever',
#   '傷痛',
#   '探討',
#   '--',
#   '瓦干達',
#   '出來',
#   '第一集',
#   '力量',
#   '超凡',
#   '光明',
#   '角色',
#   '深度',
#   '黑暗',
#   '以來',
#   '神作',
#   '續集',
#   '驚艷',
#   '爽片',
#   '---',
#   '評論',
#   '微有雷',
#   '----',
#   '人覺',
#   '導演',
#   '本來',
#   '過世後怎麼',
#   '走過',
#   '洗煉',
#   '純化',
#   '帶給',
#   '議題',
#   '裡面',
#   '父親',
#   '課題',
#   '進到',
#   '則繼續述',
#   '繼承者',
#   '過去',
#   '覺得',
#   '很強',
#   '但現',
#   '一個',
#   '一樣強',
#   '更強',
#   '對手',
#   '並且',
#   '帶來',
#   '威脅',
#   '....',
#   '還能',
#   '仁義嗎',
#   '會不會',
#   '執念裡',
#   '再來',
#   '親情',
#   '刻畫',
#   'Suri',
#   '女兒',
#   '...',
#   '面對',
#   '內有',
#   '夾殺',
#   '蛻變',
#   '情節',
#   '因為',
#   '經驗',
#   '間親',
#   '自走過',
#   '淬煉',
#   '結論',
#   '會講',
#   '戰勝',
#   '優秀',
#   '則講述',
#   '回無極',
#   '這是',
#   '2022',
#   '唯一',
#   '查德威',
#   '藏不住',
#   '掩藏',
#   '交流中心',
#   '超值',
#   '德性',
#   '非常',
#   '戒心',
#   '如何',
#   '影院',
#   '王后',
#   '深谷',
#   '奴役',
#   '手足',
#   '只想',
#   '共享',
#   '合金',
#   '世人']]

# %%
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)

# %%
diction
# Out:
# Counter({'舒莉': 7,
#          '沒有': 9,
#          '美隊': 2,
#          '強壯感': 2,
#          '但劇': 3,
#          '情上': 2,
#          '還不錯': 11,
#          '黑豹': 30,
#          '喜感': 2,
#          '阿凡': 10,
#          '瑕不掩瑜': 2,
#          '樓下': 2,
#          '黑亞當': 7,
#          '贏過': 4,
#          '黑亞': 3,
#          '當後面': 2,
#          '睡著': 7,
#          '主義': 2,
#          '這部': 12,
#          '一樣': 5,
#          '承襲': 2,
#          '宏偉': 2,
#          '每個': 4,
#          '刻劃': 2,
#          '不會輕': 2,
#          '描淡': 2,
#          '畫面': 7,
#          '一個': 8,
#          '國家': 3,
#          '水行俠': 7,
#          'FU': 2,
#          '老套': 2,
#          '美中不足': 3,
#          '超人': 2,
#          '美式': 2,
#          '特效': 11,
#          '很漂亮': 2,
#          '看到': 9,
#          '七八': 2,
#          '放屁': 2,
#          '女生': 3,
#          '角色': 10,
#          '清楚': 2,
#          '精神': 2,
#          '世界': 4,
#          '就是': 9,
#          '整體': 8,
#          '體感': 2,
#          '奇異': 2,
#          '比劇情': 2,
#          '太攏': 2,
#          '不夠': 4,
#          '湊動作': 2,
#          '戲太少': 2,
#          '緊張': 3,
#          '不會': 4,
#          '來覺': 2,
#          '電影': 21,
#          '我個': 5,
#          '人覺': 6,
#          '下來': 2,
#          '漫威': 18,
#          'DC': 4,
#          '雷神': 3,
#          '博士': 4,
#          '缺少': 3,
#          '看出': 2,
#          '一片': 4,
#          '今年': 6,
#          '所以': 3,
#          '如果': 5,
#          '心路': 3,
#          '劇情': 17,
#          '連貫': 2,
#          '歷程': 3,
#          '共鳴': 2,
#          '延續': 2,
#          '價值': 2,
#          '湊端': 2,
#          '菜色': 2,
#          '整部': 5,
#          '好吃': 2,
#          '主角': 10,
#          '不合理': 2,
#          '作品': 3,
#          '商品': 2,
#          '引起': 2,
#          '只是': 10,
#          '可能': 5,
#          '女配角': 2,
#          '本片': 3,
#          '外媒': 2,
#          '報導': 2,
#          '劇本': 2,
#          '維克': 3,
#          '博斯曼': 3,
#          '過世': 3,
#          '導演': 3,
#          '編劇': 2,
#          '改寫': 2,
#          '舒莉來': 2,
#          '實在': 2,
#          '服觀眾': 2,
#          '感覺': 8,
#          '演貓': 2,
#          '......': 3,
#          '演拉瑪達': 2,
#          '安琪拉': 2,
#          '貝瑟': 2,
#          'Angela': 2,
#          'Bassett': 2,
#          '準備': 2,
#          '入圍': 2,
#          '奧斯卡': 2,
#          '查德': 3,
#          '男主角': 2,
#          '翻新': 2,
#          '提名': 2,
#          '薄弱': 4,
#          '承接': 2,
#          '精彩': 8,
#          '身分': 2,
#          '表演': 2,
#          '皇后': 2,
#          '重新': 2,
#          '可以': 10,
#          '覺得': 11,
#          '滿有': 2,
#          '略帶': 2,
#          '不過': 2,
#          '有悶': 2,
#          '第一集': 6,
#          '好看': 28,
#          '影子': 3,
#          '深度': 5,
#          '部分': 7,
#          '一些': 6,
#          '橋段': 3,
#          '不太能': 2,
#          '心戲': 2,
#          '邏輯': 2,
#          '上實': 2,
#          '相當': 3,
#          '厲害': 3,
#          '勉強': 2,
#          '緬懷': 3,
#          'Chadwick': 2,
#          'Aaron': 2,
#          'Boseman': 2,
#          '演得': 2,
#          '演技': 7,
#          '女主角': 5,
#          '挑起': 2,
#          '女王': 2,
#          '粗糙': 3,
#          '肌肉': 2,
#          '可惜': 4,
#          '令人': 4,
#          '理解': 2,
#          '而言': 3,
#          '某些': 3,
#          '集中': 2,
#          '主要': 2,
#          '很難': 2,
#          '最難': 3,
#          '別騙': 2,
#          '系列': 2,
#          '五顆': 3,
#          '通通': 2,
#          '沙丘': 2,
#          '其它': 2,
#          '所有': 3,
#          '只有': 6,
#          '演起': 2,
#          '靈魂': 2,
#          '素人': 2,
#          '演戲': 2,
#          '小女孩': 3,
#          '像是': 3,
#          '故事': 7,
#          '比奇': 1,
#          '笑點': 1,
#          '哭點': 1,
#          '推薦': 1,
#          '到後來': 1,
#          '雖然': 2,
#          '有點長': 1,
#          '成的還': 1,
#          '但後面': 1,
#          '變成': 1,
#          '敵人': 1,
#          '還有': 3,
#          '研發': 1,
#          '出類': 1,
#          '鋼鐵人': 4,
#          '這點': 1,
#          '挺身而出': 1,
#          '草率': 1,
#          '解救': 1,
#          '打到': 1,
#          '高科技': 1,
#          '公主': 1,
#          '前面': 1,
#          '接受': 1,
#          '如何': 2,
#          '一定': 4,
#          '以及': 3,
#          '不能': 5,
#          '爽度': 3,
#          '滿頭': 1,
#          '問好': 1,
#          '身為': 2,
#          '最強': 1,
#          '之國': 1,
#          '太不經': 1,
#          '動不動': 1,
#          '當菜': 1,
#          '上映': 1,
#          '入侵': 1,
#          '基本上': 1,
#          '以外': 2,
#          '刺激': 3,
#          '除了': 5,
#          '地方': 2,
#          '顏值': 1,
#          '最爛': 3,
#          '東湊': 1,
#          '西湊': 1,
#          '好爛': 1,
#          '盜版': 2,
#          '還好': 2,
#          '音樂': 7,
#          '還算': 1,
#          '描述': 1,
#          '一部': 10,
#          '最酷': 1,
#          '羽蛇神': 1,
#          '藍人': 1,
#          '從海裡': 1,
#          '出來': 3,
#          '全片': 1,
#          '第一幕': 1,
#          '..': 4,
#          '開頭': 2,
#          '不錯': 4,
#          '這部片': 3,
#          '結果': 2,
#          '中間': 3,
#          '片長': 3,
#          '這麼': 3,
#          '發揮': 1,
#          '淘寶機器': 1,
#          '什麼': 4,
#          '鬼夜': 1,
#          '最後轉': 1,
#          '折堪': 1,
#          '終生': 1,
#          '還者': 1,
#          '一無所': 1,
#          'IMAX': 1,
#          '尿急': 1,
#          '天使': 1,
#          '期待': 4,
#          '好好': 2,
#          '不用': 3,
#          '到底': 3,
#          '根本': 4,
#          '敘述': 2,
#          '還以': 2,
#          '...': 6,
#          '比連續劇': 1,
#          '還遭': 1,
#          '一堆': 1,
#          '最近': 3,
#          '日本': 1,
#          '能力': 1,
#          '不建議': 2,
#          '進戲院': 1,
#          '一半': 1,
#          '動作': 4,
#          '場面': 1,
#          '打瞌睡': 2,
#          '音效': 1,
#          'Wakanda': 4,
#          'Forever': 4,
#          'No': 1,
#          'woman': 1,
#          'no': 1,
#          'cry': 1,
#          '探討': 2,
#          '刻畫': 3,
#          '轉折': 2,
#          '配樂': 7,
#          '依舊': 1,
#          '驚嘆': 1,
#          '樂性': 1,
#          '但視覺': 1,
#          '場景': 2,
#          '悲慘': 1,
#          '因為': 4,
#          '2D': 1,
#          '3D': 1,
#          '的關': 1,
#          '總結': 1,
#          '許無法': 1,
#          '標準': 1,
#          '8.3': 1,
#          '10': 1,
#          'Everything': 1,
#          'gonna': 1,
#          'alright': 1,
#          '人性': 2,
#          '十足': 2,
#          '唯一': 3,
#          '是不是': 1,
#          '有些': 3,
#          '知道': 1,
#          '越大': 1,
#          '導致': 2,
#          '點悶': 1,
#          '片尾': 3,
#          '結束': 2,
#          '太久': 1,
#          '一枚': 1,
#          '失望': 2,
#          '等到': 1,
#          '不太會演': 2,
#          '邊看': 1,
#          '邊哭': 1,
#          '打鬥': 6,
#          '流暢': 1,
#          '非常': 5,
#          '超級': 4,
#          '影集': 2,
#          '很無感': 1,
#          '拿來': 1,
#          '消費': 1,
#          '主軸不清': 1,
#          '氣勢': 2,
#          '敗筆': 1,
#          '鋼鐵心': 3,
#          '出現': 1,
#          '人設': 1,
#          '討喜': 1,
#          '很醜': 1,
#          '裝甲': 1,
#          '90': 1,
#          '動畫': 1,
#          '出戲': 1,
#          '整片': 2,
#          '追思': 3,
#          '卡通': 1,
#          '手法': 1,
#          '大大': 1,
#          '不如': 4,
#          '格局': 2,
#          '必要': 2,
#          '年代': 1,
#          '戲份': 1,
#          '一點': 3,
#          '打鬥戲': 3,
#          '義的': 1,
#          '情感': 4,
#          '有意': 2,
#          '認為': 1,
#          '感傷': 2,
#          '感人': 3,
#          '水貨': 1,
#          '浮誇': 1,
#          '正確': 2,
#          '毫無帶': 1,
#          '入感': 1,
#          '設計': 1,
#          '費經費': 1,
#          '絕對': 1,
#          '2022': 2,
#          '骨瘦如柴': 1,
#          '白浪': 1,
#          '大作': 1,
#          '不行': 1,
#          '印度': 1,
#          '政治': 2,
#          '之一': 1,
#          '爽片': 8,
#          '跳脫': 1,
#          '強烈': 1,
#          '喜歡': 5,
#          '無腦': 2,
#          '看過': 1,
#          '全漫威': 1,
#          '還蠻': 1,
#          '滿意': 1,
#          '美意': 1,
#          '以往': 2,
#          '超悶': 2,
#          '漫威動': 1,
#          '作片': 1,
#          '戲很拖': 1,
#          '無感': 1,
#          '很弱': 1,
#          '第一次': 2,
#          '義的片': 1,
#          '淚水': 1,
#          '影院': 5,
#          '視覺': 2,
#          '豐富': 1,
#          '史詩級': 1,
#          '的電': 1,
#          '雷包': 1,
#          '脫鞋': 1,
#          '腳抖': 1,
#          '餅乾': 1,
#          '現在': 2,
#          '人電': 1,
#          '都當': 1,
#          '排座位': 1,
#          '打手': 1,
#          '超大': 1,
#          '聊天': 1,
#          '抬起': 1,
#          '遇到': 1,
#          '直接': 2,
#          '自己': 3,
#          '一開始': 1,
#          '認真': 3,
#          '無奈中': 1,
#          '廢話': 1,
#          '白實': 1,
#          '不緊': 1,
#          '東拼西': 1,
#          '最後還': 1,
#          '平心': 1,
#          '而論': 2,
#          '但千萬': 1,
#          '螢幕': 2,
#          '觀賞': 1,
#          '家裡': 1,
#          '靜默': 2,
#          '過多到': 1,
#          '炫富': 1,
#          '荷莉': 1,
#          '貝瑞來': 1,
#          '煽情': 1,
#          '第一代': 4,
#          '完美': 1,
#          '造型': 1,
#          '要是': 1,
#          '不好': 1,
#          '似乎': 1,
#          '而是': 2,
#          '另外': 1,
#          '不是': 6,
#          '有夠': 2,
#          '水裡': 1,
#          'con': 1,
#          'la': 1,
#          'brisa': 1,
#          '就值': 1,
#          '那首': 1,
#          '光是': 1,
#          '歌曲': 1,
#          '雖然整': 1,
#          '圍繞': 2,
#          '情架構': 1,
#          '面等': 1,
#          '幾部': 1,
#          '很長': 1,
#          '當成': 1,
#          '電影來': 1,
#          '查拉': 1,
#          '色系': 1,
#          '灰暗': 1,
#          '品味': 1,
#          '前任': 1,
#          '病逝': 1,
#          '比起': 1,
#          '起源': 1,
#          '感情': 2,
#          '慢慢': 1,
#          '需要': 1,
#          '冷場': 1,
#          '到後面': 1,
#          '二刷': 3,
#          '什麼樣': 1,
#          '滿足': 1,
#          'art': 1,
#          '架構': 1,
#          '暢度': 1,
#          '這些': 1,
#          '只會批': 1,
#          '評別': 1,
#          '盤俠': 1,
#          '科科': 1,
#          '這次': 2,
#          '比較': 3,
#          '畢竟': 1,
#          '才剛': 1,
#          '沒什麼': 1,
#          '建議': 3,
#          '會爽': 1,
#          '挑剔': 1,
#          '成形': 1,
#          '不知': 1,
#          '那些': 1,
#          '其他': 1,
#          '這應': 1,
#          '....': 3,
#          '溫馨動': 1,
#          'D版': 1,
#          '值得': 3,
#          '之外': 1,
#          '王太后': 1,
#          '服裝': 1,
#          '驚艷到': 1,
#          '用心': 1,
#          '傳達': 1,
#          '反戰': 1,
#          '打動': 2,
#          '缺點': 2,
#          '練壯': 1,
#          '貓女': 1,
#          '瘦弱': 1,
#          '思念': 1,
#          '這麼爛': 1,
#          '評價給': 1,
#          '當商業': 1,
#          '美到': 1,
#          '堪稱': 1,
#          '藝術品': 1,
#          '文戲': 1,
#          '演員演': 1,
#          '女將': 1,
#          '那場': 1,
#          '演超': 1,
#          '詮釋': 1,
#          '莫納': 1,
#          '解釋': 2,
#          '超過': 1,
#          '4.5': 1,
#          '顆心': 1,
#          '最棒': 1,
#          '不要': 4,
#          '王后': 2,
#          '垃圾': 2,
#          '明明': 1,
#          '理由': 1,
#          '不起': 3,
#          '瘦小': 1,
#          '妹妹': 3,
#          '只能': 3,
#          '那麼爛': 1,
#          '較長': 1,
#          '時間': 1,
#          '本篇': 1,
#          '交代': 1,
#          '達大戰': 1,
#          '不看': 1,
#          '年輕': 1,
#          '回歸漫威': 1,
#          '..............': 1,
#          '劇透': 1,
#          '去電': 2,
#          '看才': 1,
#          '威漫': 1,
#          '退場': 1,
#          '出頭': 1,
#          '這是': 5,
#          '看威漫': 1,
#          '女英雄': 1,
#          '感想': 1,
#          '接手': 1,
#          '有意思': 1,
#          '英雄': 4,
#          '女性': 2,
#          '錢的網': 1,
#          '漫威迷': 1,
#          '滿心': 1,
#          '進電': 1,
#          '感動': 2,
#          '詳細': 1,
#          '內容': 2,
#          '動作戲': 2,
#          '在電': 1,
#          '看漫威': 1,
#          '震撼人心': 1,
#          '搭上': 1,
#          '不得不': 1,
#          '突出': 1,
#          '很多': 3,
#          '但是': 3,
#          '絕無冷場': 1,
#          '滿懷': 1,
#          '恰好': 1,
#          '原來': 1,
#          '已經': 1,
#          '海邊': 1,
#          '那幕': 1,
#          '那麼': 3,
#          '黑到': 1,
#          '母女': 1,
#          '黑人': 1,
#          '看不到': 1,
#          '本身': 2,
#          '毫無邏輯': 1,
#          '爛片': 1,
#          '浪費': 1,
#          '網紅': 1,
#          '違背': 1,
#          '宣傳': 1,
#          '良心': 1,
#          '大肆': 1,
#          '近期': 3,
#          '單純': 1,
#          '漫威式': 1,
#          '觀眾': 3,
#          '養大': 1,
#          '最後再': 1,
#          '出動作': 1,
#          '壓軸': 1,
#          '這樣': 3,
#          '的點': 1,
#          '乏味': 1,
#          '胃口': 1,
#          '加以': 1,
#          '一部分': 1,
#          '感到': 1,
#          '原因': 2,
#          '憑心': 1,
#          '大家': 2,
#          '紀念': 2,
#          '豐滿': 1,
#          '彩蛋': 4,
#          '不差': 1,
#          '保羅沃克': 1,
#          '有紀念': 1,
#          '概念': 1,
#          '好像': 1,
#          '之前': 1,
#          '近年': 1,
#          '低分': 1,
#          '千萬': 1,
#          '評分': 1,
#          '給這麼': 1,
#          '無敵': 1,
#          '創意': 1,
#          '適合': 2,
#          '這種': 3,
#          '主題': 2,
#          '面向': 1,
#          '水下': 2,
#          '本人': 1,
#          '相信': 1,
#          '習慣': 1,
#          '太像': 1,
#          '裝感覺': 1,
#          '大頭': 1,
#          '頭大身': 1,
#          '吱吱': 1,
#          '完整性': 1,
#          '娃娃': 1,
#          '無益': 1,
#          '好險': 1,
#          '手機': 1,
#          '兩次': 1,
#          '而已': 1,
#          '蠻熱鬧': 1,
#          '從片頭': 1,
#          '陰影': 1,
#          '胃痛': 1,
#          '很爽': 1,
#          '這階段': 1,
#          '不悶': 1,
#          '開外掛': 1,
#          '得獎': 1,
#          '不遜色': 1,
#          '納摩': 2,
#          '戰鬥': 1,
#          '相較': 1,
#          '完全': 2,
#          '方式': 2,
#          '神域': 1,
#          '心智': 1,
#          '小朋友': 2,
#          '霍元甲': 1,
#          '我建議': 1,
#          '內心': 2,
#          '變化': 1,
#          '鬥智': 1,
#          '葉問': 1,
#          '問兩句': 1,
#          '上測': 1,
#          '這類': 1,
#          '太難': 1,
#          '只會': 1,
#          '睡來': 1,
#          '這留': 1,
#          '隨時': 1,
#          '打刀': 1,
#          '一星': 1,
#          '一百': 1,
#          '你好': 1,
#          '昨天': 1,
#          '打呼': 1,
#          '應該': 1,
#          '黑貓': 2,
#          '老妹': 1,
#          '起來': 1,
#          '爛透': 1,
#          '進場': 1,
#          '懷念': 1,
#          '冷氣': 1,
#          '睡覺': 1,
#          '情侶': 1,
#          '抱歉': 1,
#          '隔壁': 2,
#          '直到': 1,
#          '千萬別': 1,
#          '這片': 2,
#          '週末': 1,
#          '超黑': 1,
#          '超難': 1,
#          '絕對後悔': 1,
#          '接下': 1,
#          '沈悶': 1,
#          '趕快': 1,
#          '花錢': 2,
#          '本以': 1,
#          '論爽片': 1,
#          '質感': 1,
#          '勝過': 1,
#          '廁所': 1,
#          '專心': 1,
#          '沒尿遁': 1,
#          '至少': 1,
#          '想到': 2,
#          '一次': 1,
#          'imax': 1,
#          '表現': 1,
#          '第四': 2,
#          '關影': 1,
#          '體驗': 1,
#          '過於賣': 1,
#          '情懷': 1,
#          '時候': 1,
#          '無趣': 1,
#          '煩躁': 1,
#          '繼承': 1,
#          '特別': 1,
#          '之處': 1,
#          '預告': 1,
#          '許笑點': 1,
#          '風格': 1,
#          '可憐且': 1,
#          '無力': 1,
#          '過暗': 1,
#          '問題': 3,
#          '或許': 1,
#          '演員': 1,
#          '綜觀': 1,
#          '串流': 1,
#          '電視': 1,
#          '想二刷': 1,
#          '過差': 1,
#          '墊底': 1,
#          '普到': 1,
#          '再普': 1,
#          '路罷': 1,
#          '.....': 2,
#          '少得': 1,
#          '播放': 1,
#          '辛苦': 1,
#          '即便': 1,
#          '科技': 1,
#          '相比': 1,
#          '普遍': 1,
#          '身上': 1,
#          '真正': 1,
#          '或者': 1,
#          '任何': 1,
#          '存在': 1,
#          '一直': 1,
#          '民族情': 1,
#          '親情': 2,
#          '隨著': 1,
#          '戰爭': 1,
#          '兩造': 1,
#          '失敗': 1,
#          '贏家': 1,
#          '無限': 1,
#          '瓦干達': 2,
#          '萬歲': 1,
#          '當論': 1,
#          '漫威輸': 1,
#          '有照': 1,
#          '顧喜': 1,
#          '愛爽片': 1,
#          '演化出': 1,
#          '友情': 1,
#          '仇恨': 1,
#          '半套': 1,
#          '許多場': 1,
#          '景廉': 1,
#          '價感': 1,
#          '臨演': 1,
#          '熱鬧': 1,
#          '切換': 1,
#          '人錯': 1,
#          '氣場': 1,
#          '致敬': 3,
#          '改善': 1,
#          '同樣': 1,
#          '命運': 1,
#          '搶過': 1,
#          '還比': 1,
#          '看頭': 1,
#          '幫納摩鋪': 1,
#          '配角': 1,
#          '光芒': 1,
#          '反而': 2,
#          '不足': 1,
#          '娛樂': 1,
#          '有史': 1,
#          '以來': 2,
#          '無誤': 1,
#          '遷強': 1,
#          '離譜': 1,
#          '難以': 1,
#          '僅有': 1,
#          '華麗': 1,
#          '還行': 1,
#          '信服': 1,
#          '舒利': 1,
#          '身材': 1,
#          '我覺': 2,
#          '整個': 1,
#          '紙片': 1,
#          '拉護衛': 1,
#          '奇雅': 1,
#          '演而演': 1,
#          '沒辦': 1,
#          '法當': 1,
#          '好多': 1,
#          '尤其': 1,
#          '海洋': 1,
#          'Blue': 1,
#          '樂園': 1,
#          '藍色色': 1,
#          '納摩新': 1,
#          '呈現': 1,
#          '這家': 1,
#          'CGI': 1,
#          '還要': 1,
#          '為主題': 1,
#          '旅遊': 1,
#          '季節': 1,
#          '生態館': 1,
#          '專門': 1,
#          '遊樂園': 1,
#          '漫畫': 1,
#          '還原': 1,
#          '適合給': 1,
#          '來個': 1,
#          '衝刺': 1,
#          '夏末': 1,
#          '唯美': 1,
#          '秋冬': 1,
#          '好玩': 1,
#          '搭配': 1,
#          '打造': 1,
#          '海底': 1,
#          '符合': 1,
#          '一座': 1,
#          '更是': 1,
#          '沒人': 1,
#          '來當': 1,
#          '真以': 1,
#          '會電影': 1,
#          '辦一場': 1,
#          '更爽': 1,
#          '過氣': 1,
#          '給一星': 1,
#          '大便': 1,
#          '滿難': 1,
#          '算是': 2,
#          '連續': 1,
#          '厭煩': 1,
#          '的確': 1,
#          '改進': 1,
#          '空間': 1,
#          '不太起': 1,
#          '沒人能': 1,
#          '編排': 1,
#          '因應': 1,
#          '鮑斯曼': 2,
#          '驟逝': 1,
#          '看著': 1,
#          '致上': 1,
#          '欣賞': 1,
#          '一集': 1,
#          '影迷': 1,
#          '敬意': 1,
#          '有待': 1,
#          '更好': 1,
#          '最好': 2,
#          '最高': 1,
#          '好好看': 1,
#          '片段': 1,
#          '2.5': 1,
#          '我給': 1,
#          '六顆': 1,
#          '一顆': 2,
#          '多重': 1,
#          '宇宙': 1,
#          '效果': 1,
#          '離開': 1,
#          '算紀念': 1,
#          '查德威': 2,
#          '很棒': 1,
#          '安排': 1,
#          '希望': 1,
#          '有人': 1,
#          '優秀': 2,
#          '值得一看': 1,
#          '以為': 1,
#          '記得': 1,
#          '帶衛': 1,
#          '生紙': 1,
#          '無窮': 1,
#          '回味': 1,
#          '剛看': 1,
#          '講比': 1,
#          '完覺': 1,
#          '故事性': 1,
#          '落差': 1,
#          '反派': 1,
#          '小時': 1,
#          '41': 1,
#          '開始': 1,
#          '偶爾': 1,
#          '預告片': 1,
#          '水行種': 1,
#          '可進': 1,
#          '戲院': 1,
#          '穿插': 1,
#          '可想而知': 1,
#          '打架': 1,
#          '可不': 1,
#          '小小的': 1,
#          '蜘蛛人': 1,
#          '尚氣排': 1,
#          '看得出': 1,
#          '第三': 1,
#          '第二': 1,
#          '第二集': 1,
#          '傷痛': 1,
#          '--': 1,
#          '力量': 1,
#          '超凡': 1,
#          '光明': 1,
#          '黑暗': 1,
#          '神作': 1,
#          '續集': 1,
#          '驚艷': 1,
#          '---': 1,
#          '評論': 1,
#          '微有雷': 1,
#          '----': 1,
#          '本來': 1,
#          '過世後怎麼': 1,
#          '走過': 1,
#          '洗煉': 1,
#          '純化': 1,
#          '帶給': 1,
#          '議題': 1,
#          '裡面': 1,
#          '父親': 1,
#          '課題': 1,
#          '進到': 1,
#          '則繼續述': 1,
#          '繼承者': 1,
#          '過去': 1,
#          '很強': 1,
#          '但現': 1,
#          '一樣強': 1,
#          '更強': 1,
#          '對手': 1,
#          '並且': 1,
#          '帶來': 1,
#          '威脅': 1,
#          '還能': 1,
#          '仁義嗎': 1,
#          '會不會': 1,
#          '執念裡': 1,
#          '再來': 1,
#          'Suri': 1,
#          '女兒': 1,
#          '面對': 1,
#          '內有': 1,
#          '夾殺': 1,
#          '蛻變': 1,
#          ...})

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
mask = np.array(Image.open("555.jpeg"))
font = "C:\Windows\Fonts\MSJH.TTC"

# %%
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# %%
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
