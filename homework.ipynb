# %%
import pandas as pd

#read the csv
a=pd.read_csv("16.csv")
b=pd.read_csv("712.csv")
print(a)
print(a.equals(b),"代表兩筆資料維度不同")

print(len(a),len(b))
# Out:
#                         發生時間                            發生地點   死亡受傷人數  \
# 0       110年01月01日 00時02分38秒    臺南市安平區中華西路2段口 / 臺南市安平區永華路2段口  死亡0;受傷1
# 1       110年01月01日 00時05分00秒                 臺東縣蘭嶼鄉東80線8.6公里  死亡0;受傷1
# 2       110年01月01日 00時05分00秒  臺中市西屯區上安里臺灣大道三段 / 臺中市西屯區上安里朝富路  死亡0;受傷2
# 3       110年01月01日 00時05分20秒                 屏東縣三地門鄉台24線21公里  死亡0;受傷1
# 4       110年01月01日 00時09分00秒                  屏東縣新園鄉興安路與新南路口  死亡0;受傷1
# ...                      ...                             ...      ...
# 174076  110年06月30日 23時15分46秒    臺南市麻豆區縣173線 2公里500.0公尺處南側向外側  死亡0;受傷1
# 174077  110年06月30日 23時20分00秒                  臺南市永康區中華路349號前  死亡0;受傷1
# 174078  110年06月30日 23時48分00秒         臺中市北區建成里南京東路二段13號前0.0公尺  死亡0;受傷1
# 174079     資料提供日期：111年07月01日                             NaN      NaN
# 174080              事故類別：A2類                             NaN      NaN
#
#                                                      車種          經度         緯度
# ...

# %%
a.tail()
# Out:
#                         發生時間                          發生地點   死亡受傷人數  \
# 174076  110年06月30日 23時15分46秒  臺南市麻豆區縣173線 2公里500.0公尺處南側向外側  死亡0;受傷1
# 174077  110年06月30日 23時20分00秒                臺南市永康區中華路349號前  死亡0;受傷1
# 174078  110年06月30日 23時48分00秒       臺中市北區建成里南京東路二段13號前0.0公尺  死亡0;受傷1
# 174079     資料提供日期：111年07月01日                           NaN      NaN
# 174080              事故類別：A2類                           NaN      NaN
#
#                                                      車種          經度         緯度
# 174076                          自用-小貨車(含客、貨兩用);腳踏自行車-慢車  120.246403  23.165014
# 174077  普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車  120.233859  23.008388
# 174078                                   普通重型-機車;自用-小客車  120.697762  24.152279
# 174079                                              NaN         NaN        NaN
# 174080                                              NaN         NaN        NaN

# %%
pd.DataFrame(a)
pd.DataFrame(b)
# Out:
#                         發生時間                         發生地點   死亡受傷人數  \
# 0       110年07月01日 00時01分00秒          高雄市楠梓區村楠興東路.號前0.0公尺  死亡0;受傷1
# 1       110年07月01日 00時12分00秒          新北市蘆洲區和平路112號前0.0公尺  死亡0;受傷3
# 2       110年07月01日 00時31分00秒      高雄市苓雅區村中正一路 / 高雄市苓雅區正言路  死亡0;受傷1
# 3       110年07月01日 00時37分00秒  桃園市中壢區中山東路2段口 / 桃園市中壢區環中東路口  死亡0;受傷1
# 4       110年07月01日 00時39分00秒              桃園市桃園區國際路一段639號  死亡0;受傷1
# ...                      ...                          ...      ...
# 182333  110年12月31日 23時53分02秒        金門縣金寧鄉湖下196號(湖埔國小)旁路口  死亡0;受傷1
# 182334  110年12月31日 23時54分00秒     臺北市信義區和平東路3段 / 臺北市信義區信安街  死亡0;受傷1
# 182335  110年12月31日 23時56分00秒          臺北市北投區泉源路242號前0.0公尺  死亡0;受傷2
# 182336     資料提供日期：111年07月01日                          NaN      NaN
# 182337              事故類別：A2類                          NaN      NaN
#
#                                  車種          經度         緯度
# 0                           普通重型-機車  120.333000  22.719780
# ...

# %%
aa=list(a['車種'])
list=aa.split(",")
bb=list(b['車種'])
bb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 aa=list(a['車種'])
# ----> 2 list=aa.split(",")
#       3 bb=list(b['車種'])
#       4 bb
#
# AttributeError: 'list' object has no attribute 'split'

# %%
aaa
# Out:
# ['自用-小客車;普通重型-機車',
#  '普通重型-機車',
#  '大型重型1(550C.C.以上)-機車;普通重型-機車',
#  '普通重型-機車;自用-小客車',
#  '普通重型-機車;自用-小客車',
#  '普通重型-機車;普通重型-機車;乘客-人;乘客-人',
#  '計程車-小客車;普通重型-機車',
#  '自用-小客車;行人-人',
#  '自用-小客車',
#  '普通重型-機車;自用-小客車;乘客-人',
#  '普通重型-機車;自用-小客車',
#  '自用-小客車;自用-小客車;普通重型-機車',
#  '普通重型-機車;普通重型-機車',
#  '電動自行車-慢車;自用-小客車',
#  '自用-小客車;普通重型-機車;乘客-人',
#  '行人-人;普通重型-機車',
#  '普通重型-機車;自用-小客車',
#  '自用-小貨車(含客、貨兩用);自用-小客車;乘客-人',
#  '普通重型-機車;自用-小客車',
#  '普通重型-機車;普通重型-機車',
#  '自用-小客車;普通重型-機車',
#  '普通重型-機車;普通重型-機車',
#  '自用-小客車',
#  '自用-小客車;自用-小客車',
#  '計程車-小客車;普通重型-機車;乘客-人',
#  '普通重型-機車',
#  '自用-小客車;普通重型-機車;乘客-人',
#  '普通重型-機車;普通重型-機車',
#  '普通重型-機車',
#  '普通重型-機車;普通重型-機車',
#  '行人-人;普通重型-機車',
#  '自用-小客車;自用-小客車;自用-小客車;乘客-人;乘客-人;乘客-人;乘客-人;乘客-人',
#  '自用-小客車;普通重型-機車',
#  '普通重型-機車',
#  '普通重型-機車;自用-小客車;普通重型-機車',
#  '普通重型-機車;普通重型-機車',
#  '普通重型-機車;普通重型-機車;乘客-人',
#  '普通重型-機車;自用-小客車',
#  '大型重型2(250-550C.C.)-機車;普通重型-機車',
#  '自用-小客車;普通重型-機車;乘客-人',
#  '普通重型-機車;自用-小客車',
#  '普通重型-機車',
#  '自用-小貨車(含客、貨兩用);自用-小客車',
# ...

# %%
set(aa).difference(set(bb))
# Out:
# {'普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;普通重型-機車;自用-小客車',
#  '電動自行車-慢車;腳踏自行車-慢車;自用-小貨車(含客、貨兩用);自用-小客車',
#  '公營客運-大客車;自用-小客車',
#  '計程車-小客車;民營公車-大客車;普通重型-機車',
#  '自用-小客車;自用大客車-大客車;自用-小客車;乘客-人',
#  '其他人-人;自用-小客車;自用-小客車;自用-小客車;自用-小客車',
#  '自用-小客車;自用-小客車;大型重型1(550C.C.以上)-機車;行人-人;乘客-人',
#  '普通重型-機車;普通重型-機車;乘客-人;自用-小客車;自用-小客車',
#  '其他慢車-慢車;乘客-人',
#  '營業用-曳引車;自用-小客車;乘客-人;乘客-人;乘客-人',
#  '民營客運-大客車;大型重型1(550C.C.以上)-機車;大型重型1(550C.C.以上)-機車',
#  '行人-人;普通重型-機車;租賃車-小客車',
#  '普通重型-機車;自用-小貨車(含客、貨兩用);自用-小客車;自用-小貨車(含客、貨兩用);乘客-人',
#  '拼裝車-其他車;普通重型-機車;乘客-人;乘客-人',
#  '民營客運-大客車;其他人-人',
#  '自用-小客車;自用-小貨車(含客、貨兩用);自用-小客車;乘客-人;乘客-人;乘客-人;乘客-人',
#  '民營公車-大客車;普通輕型-機車;乘客-人',
#  '租賃車-小客車;大型重型2(250-550C.C.)-機車;普通重型-機車;乘客-人',
#  '營業用-大貨車;營業用-半聯結車;乘客-人',
#  '普通重型-機車;普通重型-機車;普通輕型-機車;普通重型-機車;普通重型-機車;普通重型-機車',
#  '自用-小客車;營業用-大貨車;自用-大貨車',
#  '自用-小貨車(含客、貨兩用);自用-小貨車(含客、貨兩用);自用-大貨車;乘客-人',
#  '自用-小客車;自用-小貨車(含客、貨兩用);電動自行車-慢車',
#  '普通重型-機車;大型重型2(250-550C.C.)-機車;自用-大貨車',
#  '動力機械-其他車;民營客運-大客車;乘客-人;乘客-人',
# ...

# %%
set1=a
set2=b

# %%
set1-set2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\anaconda\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File D:\anaconda\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File D:\anaconda\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...
